# %%
import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
from PIL import Image
import time
import pandas as pd

import os
from scipy import ndimage, misc
import glob
# Out:
# /Users/avinashk94/anaconda3/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
data = pd.read_csv('files/Anno/list_attr_celeba.txt', delim_whitespace = True, header=1)
df = data['Eyeglasses']

# %%
df.shape
# Out:
# (202599,)

# %%
# images = []

# for root, dirnames, filenames in os.walk("files/Img/img_align_celeba"):
#     for filename in filenames:
#         if ".jpg" in filename:
#             filepath = os.path.join(root, filename)
#             image = ndimage.imread(filepath)
# #             image = misc.imresize(image, (28, 28))
#             images.append(image)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-2c1c29915900> in <module>()
#       5         if ".jpg" in filename:
#       6             filepath = os.path.join(root, filename)
# ----> 7             image = ndimage.imread(filepath)
#       8             images.append(image)
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/ndimage/io.py in imread(fname, flatten, mode)
#      22 def imread(fname, flatten=False, mode=None):
#      23     if _have_pil:
# ---> 24         return _imread(fname, flatten, mode)
#      25     raise ImportError("Could not import the Python Imaging Library (PIL)"
#      26                       " required to load image files.  Please refer to"
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/misc/pilutil.py in imread(name, flatten, mode)
#     154     """
#     155
# --> 156     im = Image.open(name)
# ...

# %%
img = ndimage.imread('files/Img/img_align_celeba/000001.jpg')

# %%
np.shape(img)
# Out:
# (218, 178, 3)

# %%
from matplotlib.pyplot import imshow
# %matplotlib inline
imshow(img)

# %%
from PIL import Image
import glob
image_list = []
for filename in glob.glob('files/Img/img_align_celeba/*.jpg'): #assuming gif
    im=Image.open(filename)
    image_list.append(im)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/avinashk94/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-9f3cea326138>", line 5, in <module>
#     im=Image.open(filename)
#   File "/Users/avinashk94/anaconda3/lib/python3.6/site-packages/PIL/Image.py", line 2477, in open
#     fp = builtins.open(filename, "rb")
# OSError: [Errno 24] Too many open files: 'files/Img/img_align_celeba/185602.jpg'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/avinashk94/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1806, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# ...
